# %%
import os
import pandas as pd
hotel_reservations=pd.read_csv('Hotel Reservations.csv')
print (hotel_reservations.head())
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
df2=list(hotel_reservations.columns)
print(df2)
# Out:
# ['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space', 'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'market_segment_type', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests', 'booking_status']

# %%
datatypes=hotel_reservations.dtypes
print(datatypes)
# Out:
# Booking_ID                               object
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# room_type_reserved                       object
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                      object
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %%
hotel_reservations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
hotel_reservations[['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'required_car_parking_space', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests' ]].mean()
# Out:
# no_of_adults                               1.844962
# no_of_children                             0.105279
# no_of_weekend_nights                       0.810724
# no_of_week_nights                          2.204300
# required_car_parking_space                 0.030986
# lead_time                                 85.232557
# arrival_year                            2017.820427
# arrival_month                              7.423653
# arrival_date                              15.596995
# repeated_guest                             0.025637
# no_of_previous_cancellations               0.023349
# no_of_previous_bookings_not_canceled       0.153411
# avg_price_per_room                       103.423539
# no_of_special_requests                     0.619655
# dtype: float64

# %%
hotel_reservations[['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'required_car_parking_space', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests' ]].mode()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     0                  2
#
#    required_car_parking_space  lead_time  arrival_year  arrival_month  \
# 0                           0          0          2018             10
#
#    arrival_date  repeated_guest  no_of_previous_cancellations  \
# 0            13               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0                65.0
#
#    no_of_special_requests
# 0                       0

# %%
hotel_reservations[['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'required_car_parking_space', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests' ]].std()
# Out:
# no_of_adults                             0.518715
# no_of_children                           0.402648
# no_of_weekend_nights                     0.870644
# no_of_week_nights                        1.410905
# required_car_parking_space               0.173281
# lead_time                               85.930817
# arrival_year                             0.383836
# arrival_month                            3.069894
# arrival_date                             8.740447
# repeated_guest                           0.158053
# no_of_previous_cancellations             0.368331
# no_of_previous_bookings_not_canceled     1.754171
# avg_price_per_room                      35.089424
# no_of_special_requests                   0.786236
# dtype: float64

# %%
hotel_reservations[['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'required_car_parking_space', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests' ]].median()
# Out:
# no_of_adults                               2.00
# no_of_children                             0.00
# no_of_weekend_nights                       1.00
# no_of_week_nights                          2.00
# required_car_parking_space                 0.00
# lead_time                                 57.00
# arrival_year                            2018.00
# arrival_month                              8.00
# arrival_date                              16.00
# repeated_guest                             0.00
# no_of_previous_cancellations               0.00
# no_of_previous_bookings_not_canceled       0.00
# avg_price_per_room                        99.45
# no_of_special_requests                     0.00
# dtype: float64

# %%
df3=hotel_reservations[['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'required_car_parking_space', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests' ]].min()
print(df3)
# Out:
# no_of_adults                               0.0
# no_of_children                             0.0
# no_of_weekend_nights                       0.0
# no_of_week_nights                          0.0
# required_car_parking_space                 0.0
# lead_time                                  0.0
# arrival_year                            2017.0
# arrival_month                              1.0
# arrival_date                               1.0
# repeated_guest                             0.0
# no_of_previous_cancellations               0.0
# no_of_previous_bookings_not_canceled       0.0
# avg_price_per_room                         0.0
# no_of_special_requests                     0.0
# dtype: float64

# %%
df4= hotel_reservations[['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'required_car_parking_space', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests' ]].max()
print(df4)
# Out:
# no_of_adults                               4.0
# no_of_children                            10.0
# no_of_weekend_nights                       7.0
# no_of_week_nights                         17.0
# required_car_parking_space                 1.0
# lead_time                                443.0
# arrival_year                            2018.0
# arrival_month                             12.0
# arrival_date                              31.0
# repeated_guest                             1.0
# no_of_previous_cancellations              13.0
# no_of_previous_bookings_not_canceled      58.0
# avg_price_per_room                       540.0
# no_of_special_requests                     5.0
# dtype: float64

# %%
range=df4-df3
print (range)
# Out:
# no_of_adults                              4.0
# no_of_children                           10.0
# no_of_weekend_nights                      7.0
# no_of_week_nights                        17.0
# required_car_parking_space                1.0
# lead_time                               443.0
# arrival_year                              1.0
# arrival_month                            11.0
# arrival_date                             30.0
# repeated_guest                            1.0
# no_of_previous_cancellations             13.0
# no_of_previous_bookings_not_canceled     58.0
# avg_price_per_room                      540.0
# no_of_special_requests                    5.0
# dtype: float64

# %%
hotel_reservations[['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space', 'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'market_segment_type', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests', 'booking_status']].value_counts()
# Out:
# Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  type_of_meal_plan  required_car_parking_space  room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  repeated_guest  market_segment_type  no_of_previous_cancellations  no_of_previous_bookings_not_canceled  avg_price_per_room  no_of_special_requests  booking_status
# INN36275    2             0               1                     2                  Meal Plan 1        0                           Room_Type 1         207        2018          12             30            0               Offline              0                             0                                     161.67              0                       Not_Canceled      1
# ...

# %%
hotel_reservations[['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space', 'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'market_segment_type', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests', 'booking_status']].nunique()
# Out:
# Booking_ID                              36275
# no_of_adults                                5
# no_of_children                              6
# no_of_weekend_nights                        8
# no_of_week_nights                          18
# type_of_meal_plan                           4
# required_car_parking_space                  2
# room_type_reserved                          7
# lead_time                                 352
# arrival_year                                2
# arrival_month                              12
# arrival_date                               31
# repeated_guest                              2
# market_segment_type                         5
# no_of_previous_cancellations                9
# no_of_previous_bookings_not_canceled       59
# avg_price_per_room                       3930
# no_of_special_requests                      6
# booking_status                              2
# dtype: int64

# %%
hotel_reservations[['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space', 'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'market_segment_type', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests', 'booking_status']].isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# repeated_guest                          0
# market_segment_type                     0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
hotel_reservations[['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space', 'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'market_segment_type', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests', 'booking_status']].isna().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# repeated_guest                          0
# market_segment_type                     0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
duplicates= hotel_reservations.duplicated()
print (duplicates)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36270    False
# 36271    False
# 36272    False
# 36273    False
# 36274    False
# Length: 36275, dtype: bool
